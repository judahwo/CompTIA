# %% [markdown]
# # Comp TIA
#
# **Website:** [Computing Technology Industry Association](https://www.comptia.org/home)
#
# ## Network + Certification<br>
# - 3 years
# - indefinite A + certification
#
# ## Security + Certification<br>
# - 3 years
# - indefinite A + certification
# - or Network + certification
#
# **Test Breakdown**<br>
# Domain 1: Neworking Concepts 23%<br>
# Domain 2: Network Implementation 20%<br>
# Domain 3: Network Operations 19%<br>
# Domain 4: Network Security 14%<br>
# Domain 5: Network Troubleshooting and Tools 24%<br>

# %% [markdown]
# ## Exam Tips
#
# 1. There will be no trick questions
# 2. Lookout for distractors or red herrings
# 3. Pay close attention to words in bold, italic, or uppercase
# 4. Answer questions based on CompTIA official documentation
# 5. Don't fight questions on the exam

# %% [markdown]
# ## Network Fundamentals
#
# Course: [Network Fundamental](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185518#content)
#
# **This Section Covers:**<br>
# Domain 1: Networking Concepts
#     - Objective 1.2: Compare and contrast network appliances, applications, and functions.
#     - Objective 1.6: Compare and contrast network topologies, architectures, and types.
# Domain 2: Network Implementation
#     - Given a scenario, select and configure wireless devices and technologies
#
# **Topics**<br>
# - Network Components
# - Network Resources
# - Network Geography
# - Wired Network Topologies
# - Wireless Network Topologies
# - Datacenter Architecture
# - Review

# %% [markdown]
# ### Network Components
#
# **Course** [Network Components](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185520#content)
#
# **Clients**<br>
# - Devices that users access the network with
# - Examples: desktops, laptops, tablets, smartphones, printers, etc.
#
# **Servers**<br>
# - Provide resources to the network
# - Examples: file servers, print servers, web servers, etc.
#
# **Hub**<br>
# - Older netword devices
# - Connects multiple devices like clients and servers over a local area network (LAN)
# - Hubs evovled into brides, and then switches over time
#
# **Switch**<br>
# - "Smarter Hubs"
# - Provide more security and efficient bandwidth utilization
#
# **Wireless Access Point (WAPs/APs)**<br>
# - Allow wireless devices to connect to the wired network
#
# **Router**<br>
# - Connects multiple networks together
# - Routes traffic between networks
#
# **Firewall**<br>
# - Protects the network from unauthorized access
# - Filters traffic based on rules
#
# **Load Balancer**<br>
# - Distributes traffic across multiple servers
# - Ensures no single server is overwhelmed
#
# **Proxy Server**<br>
# - Acts as an intermediary between clients and servers
# - Caches web pages to improve performance
# - Web filtering
# - Shared network connections
# - Data caching
# - Enhanced security and privacy
#
# **Intrustion Detection System (IDS)**<br>
# - Monitors network traffic for suspicious activity
# - Alerts administrators to potential security threats
#
# **Intrustion Prevention System (IPS)**<br>
# - Monitors network traffic for suspicious activity
# - Can take action to prevent security threats
#
# **Controller**<br>
# - Manages multiple access points in a wireless network
# - Provides centralized management and configuration
#
# **Network Attached Storage (NAS)**<br>
# - Storage device that connects to the network
# - Provides file storage to clients and servers
#
# **Storage Area Network (SAN)**<br>
# - High-speed network that connects storage devices to servers
# - Provides block-level storage to servers
#
# **Media**<br>
# - Physical layer of the network
# - Examples: copper, fiber, wireless
#
# **Wide Area Network (WAN) Technologies**<br>
# - Connects multiple LANs together
# - Examples: T1, T3, DSL, cable, fiber, etc.

# %% [markdown]
# ### Network Resources
#
# **Course** [Network Resources](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185522#content)
#
# **Client Server Model**<br>
# - Clients request resources from servers
# - Servers provide resources to clients
# - Administration and management
#     - Centralized administration
#     - Easier management
#     - Scalability
# - Some downsides
#     - Costs more
#     - Requires dedicated OS
#     - Requires specialized skillset
#
# **Peer-to-Peer Model**<br>
# - Clients share resources with each other
# - No centralized server
# - Benefits
#     - Lower cost
#     - No dedicated OS
#     - No dedicated resources
# - Some downsides
#     - Security concerns
#     - Inefficient for large networks
#     - Decentralized management
#     - Scalability issues
#
# A **peer-to-peer network** model does not differentiate between the clients and the servers, and every node can become a client and a server when requesting and responding to service requests. In a **client-server network model**, there is a clear distinction between client devices that request services and server devices that provide services. A **Point-to-point network** is a direct connection between two devices. One device acts as the sender and the other as the receiver. A **Hub-and-spoke network** model has a central hub that connects other devices (spokes). The hub provides services to the spokes.

# %% [markdown]
# ### Network Geography
#
# **Course** [Network Geography](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185524#content)
#
# **Personal Area Network (PAN)**<br>
# - Smallest type of network
# - Usually covers a distance of 10 meters or less
# - Examples: Bluetooth, USB
#
# **Local Area Network (LAN)**<br>
# - Covers a small geographic area
# - Usually confined to a single building or campus
# - Usually covers a distance of 100 meters or less
# - Examples: Ethernet, Wi-Fi
#     - Wi-Fi: IEEE 802.11
#     - Ethernet: IEEE 802.3
#
# **Campus Area Network (CAN)**<br>
# - Covers a larger geographic area
# - Usually covers a distance up to several kilometers
# - Examples: college campus, business park, military base
#
# **Metropolitan Area Network (MAN)**<br>
# - Covers a city or metropolitan area
# - Usually covers a distance up to 50 kilometers
# - Examples: mutliple colleges, department of motor vehicles, etc.
#
# **Wide Area Network (WAN)**<br>
# - Covers a large geographic area
# - Across a state, country, or even the world
# - Examples: Internet, MPLS, Frame Relay, etc.
#
# A **campus area network** (CAN) is a computer network that spans a limited geographic area. CANs interconnect multiple **local area networks** (LAN) within an educational or corporate campus. A WAN (**Wide Area Network**) is a network that spans a large geographical area, such as multiple cities or countries. A PAN (**Personal Area Network**) is a network that connects devices within an individual's personal space, typically within a range of a few meters. A MAN (**Metropolitan Area Network**) is a network that spans a larger area than a LAN (**Local Area Network**), often covering a city or a metropolitan area.

# %% [markdown]
# ### Wired Network Topologies
#
# **Course** [Wired Network Topologies](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185530#content)
#
# **What is a Network Topology?**<br>
# - Referes to the physical layout of the network
# - Determines how devices are connected
# - Determines how data flows through the network
# - Examples: links,nodes, client, server, etc.
# - Makes up a computer network
#
# **Phyiical Topologies**<br>
# - Used to show how devices are physically connected
# - Examples: floor plan, building layout, etc.
#
# **Logical Topologies**<br>
# - Used to show how data flows through the network
# - Examples: logical diagrams, network maps, etc.
#
# **Point-to-Point Topology**<br
# - Connects two devices directly
# - Examples: serial cable, USB cable, etc.
# - Pros: simple, inexpensive, easy to install for small scale
# - Cons: limited scalability, single point of failure
#
# **Ring Topology**<br>
# - Connects devices in a circular fashion
# - Data flows in one direction
# - Examples: Token Ring, FDDI, etc.
# - Pros: simple, easy to install, inexpensive
# - Cons: single point of failure, limited scalability, performance issues
#
# **Bus Topology**<br>
# - Connects network devices to a single central cable
# - Called a bus or backbone
# - Pros: easy to install, inexpensive, requires less cable
# - Cons: single point of failure, limited scalability, performance issues
#
# **Star Topology**<br>
# - Most common used today
# - Connects devices to a central router, hub, or switch
# - Connects back to a central point
# - If centrail point fails, the network fails
# - Pros: good for centralized management
# - Cons: single point of failure, relies on central device
#
# **Hub and Spoke Topology**<br>
# - Connects multiple star topologies together
# - Central hub connects to multiple spokes
# - Pros: good for centralized management
# - Cons: single point of failure, relies on central device
#
# **Mesh Topology**<br>
# - Features a point-to-point connection between every device on the network
# - Fully meshed: every device connects to every other device
#     - Pros: fault tolerance, redundancy, scalability
#     - Cons: expensive, complex, difficult to manage
# - Partially meshed: some devices connect to every other device
#     - Pros: less expensive, less complex, easier to manage
#
# A **mesh topology** connects every endpoint to every other endpoint, creating a fully redundant network. While a **hybrid topology** combines different topologies, it does not inherently provide full redundancy. The redundancy level depends on the specific combination of topologies used. In a **bus topology**, all devices are connected to a single shared communication line. If a device on it fails, the entire network can be affected. It lacks redundancy. In a **star topology**, devices are connected to a central hub or switch. If the hub or switch fails, the network can be disrupted.
#
# A **hub and spoke topology** is a network topology where a central device (the hub) is connected to multiple other devices (the spokes). A **Bus topology** has a single communication line where all devices are connected. It does not have distinct hubs and spokes. A **star topology** has a central hub that connects all devices in a point-to-point manner. While the Dion Worldwide network has hubs, not a single central hub connecting all devices. A **Ring topology** connects devices in a circular manner, where each device is connected to two neighboring devices. It doesn’t have distinct hubs and spokes.

# %% [markdown]
# ### Wireless Network Topologies
#
# **Course** [Wireless Network Topologies](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185532#content)
#
# **Infrastructure Mode**<br>
# - Wireless devices connect to a central access point
# - similar to a star topology
#
# **Ad Hoc Mode**<br>
# - Wireless devices connect directly to each other
# - No central access point
#
# **Mesh Mode**<br>
# - An interconnecion of different types of nodes, devices, and radios
# - Bluetooth, Wi-Fi, Cellular, Microwave, Satellite, etc.
# - Two or more different technologies working together

# %% [markdown]
# ### Datacenter Architecture
#
# **Course** [Datacenter Architecture](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185534#content)
#
# **Datacenter**<br>
# - A facility that houses servers, storage, and networking equipment
# - Provides centralized resources to the network
# - Examples: Google, Amazon, Microsoft, etc.
#
# **3-Tier Hierarchical Model**<br>
# - Core Layer: high-speed backbone
#     - biggest, fastest, most expensive
# - Distribution Layer: connects core to access layer
#     - connects core to access layer
# - Access Layer: connects clients to the network
#     - connects clients to the network
#
# **Collapsed Core Model**<br>
# - Core and distribution layers are combined into one layer
# - Simplifies the network design
# - Reduces the number of devices
# - May not be as scalable as the 3-tier model, not suitable for large or complex networks
#
# **Spine-Leaf Model**<br>
# - Alternative type of network architecture
# - Focuses on communication within the datacenter itself
# - faster speeds and lower latency than 3-tier model
# - Spine: connects switches in a full mesh topology
# - Leaf: consists of all the access switches
#
# **Traffic Flow**<br>
# - North-South: refers to traffic flow that enters or leaves the datacenter from a system phycially outside the datacenter
#     - North: traffic exits the datacenter
#     - South: traffic enters the datacenter
#     - Traffice enters/exits through firewall or router
# - East-West: refers to traffic flow within the data center

# %% [markdown]
# ## OSI Model
#
# **Course** [OSI Model](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185536#content)
#
# **OSI Model**<br>
# - Open Systems Interconnection Model
# - Developed by the International Organization for Standardization (ISO)
#
# **Domain 1: Networking Concepts**<br>
# - Objective 1.1: Explain concepts related to the Open Systems Interconnection (OSI) model
#
# **Reference Model**<br>
# - Used to categorize the functions of a network in the OSI Model during troubleshooting efforts
# - Networks today operate under TCP/IP model
#
# **OSI Model Layers**<br>
# - Please Do Not Throw Sausage Pizza Away
# - Physical, Data Link, Network, Transport, Session, Presentation, Application
#
# 1. **Physical Layer**<br>
#     - Layer 1
#     - Transmits raw data bits over a physical medium
#     - Examples: cables, connectors, switches, etc.
#
# 2. **Data Link Layer**<br>
#     - Layer 2
#     - Provides error detection and correction
#     - Examples: switches, bridges, NICs, etc.
#
# 3. **Network Layer**<br>
#     - Layer 3
#     - Provides logical addressing and routing
#     - Examples: routers, IP addresses, etc.
#
# 4. **Transport Layer**<br>
#     - Layer 4
#     - Provides end-to-end communication
#     - Examples: TCP, UDP, etc.
#
# 5. **Session Layer**<br>
#     - Layer 5
#     - Establishes, maintains, and terminates connections
#     - Examples: NetBIOS, PPTP, etc.
#
# 6. **Presentation Layer**<br>
#     - Layer 6
#     - Translates data into a format that can be understood by the application
#     - Examples: encryption, decryption, etc.
#
# 7. **Application Layer**<br>
#     - Layer 7
#     - Provides network services to applications
#     - Examples: HTTP, FTP, etc.

# %% [markdown]
# ### Layer 1: Physical Layer
#
# **Course** [Physical Layer](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185546#content)
#
# **Physical Layer**<br>
# - where bits are transmitted over a physical medium
# - includes physcial and elecletrical network components
# - examples: ethernet, fiber, copper, etc.
# - Layer 1 devices view networks from a physical topology perspective
#
# **Transition Modulation**<br>
# - If it changes during the clock cycle, then 1 is represented, otherwise 0 is represented
#
# **Synchronizing Communication**<br>
# - Asynchronous: no clock signal
#     - uses start and stop bits
#     - indicates when transmissions occur from the sender to the receiver
# - Synchronous: clock signal
#     - uses a clock signal to synchronize transmissions
#     - data is sent in a continuous stream
#
# **Bandwidth**<br>
# - Broadband: high-speed data transmission
#     - divides bandwidth into multiple channels
# - Baseband: single channel data transmission
#     - all frequency of the cable all of the time
#     - uses a reference clock
#
# **Time-Division Multiplexing (TDM)**<br>
# - Each session takes a turn transmitting data
# - Shares the medium between all usesrs via time slots
#
# **Statistical Time-Division Multiplexing (STDM)**<br>
# - Dynamically allocates the time slots on an as-needed basis
# - More efficient than TDM
#
# **Frequency-Division Multiplexing (FDM)**<br>
# - Divides the medium into channels based on frequesncy
# - Each session is transmitted on a different channel
#
# **Multiplexing**<br>
# - involves optimizing a limited amout of resources for more efficient utilization
#
# **Examples of Layer 1 Devices**<br>
# - fiber optic cable
# - copper cable
# - ethernet cable
# - coaxial cable
# - bluetooth
# - wifi
# - near field communication (NFC)
# - Hubs
# - Access Points
# - Media converters
#
# Layer 1 devices have no logic or intelligence, they simply repeat what they are told. They are essentially repeaters passing along whatever is received.

# %% [markdown]
# ### Layer 2: Data Link Layer
#
# **Course** [Data Link Layer](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185548#content)
#
# **Data Link Layer**<br>
# - Packages data into frames
# - Transmits those frames on the network
#
# **MAC Address**<br>
# - Media Access Control Address
# - Unique identifier for network devices
# - Physical addressing system of a device
# - Operates on a logical topology
# - every manufacturer assigns a unique MAC address to each device
# - 48-bit address
# - 24-bit Vendor ID
# - 24-bit Unique ID
#
# **Logical Link Control (LLC)**<br>
# - Provides connection services and allows acknowledgement of receipt messages
# - Most basic form of flow control
# - Gives basic error control functions
#
# **Communication Across Layer 2**<br>
# - Isochronous: devices use common reference clock and create time slots for transmission
# - Syncronous: devices agree on clocking method to indicate beginning and end of frames and can use control character
# - Asynchronous: devices reference internal clocks and use start and stop bits for synchronization
#
# **Layer 2 Devices**<br>
# - Network Interface Cards (NICs)
# - Switches
# - Bridges
# - MAC Addresses

# %% [markdown]
# ### Layer 3: Network Layer
#
# **Course** [Network Layer](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185550#content)
#
# **Network Layer**<br>
# - Provides logical addressing and routing
# - IPV4 and IPV6
#
# **Logical Addressing**<br>
# - Logical addressing is used to identify devices on a network
# - Examples: IP addresses, MAC addresses, etc.
#
# **Routing**<br>
# - Packet Switching
#     - data is divided into packets and then forwarded
#     - most common form of switching
# - Circuit Switching
#     - data is sent over a dedicated circuit
#     - conastant communication path
# - Message Switching
#     - data is divided into meassages and then forwarded
#
# **Route Discovery and Selection**<br>
# - Manually configued as a static route or dynamically through a routing protocol
# - Routing Protocols: RIP, OSPF, EIGRP, BGP, etc.
# - Routing prococals help us decide how data is going to flow, and how the routers are going to communicate that information
#
# **Connection Services**<br>
# - Augment Layer 2 connection services to improve reliability and efficiency
# - Flow control
# - Packet reordering
#     - ensures all data reaches receiver correctly at the end desitination
#
# **Internet Control Message Protocol (ICMP)**<br>
# - ping most commonly used
# - sends out packets to check connectivity
# - traceroute: checks the path of the packet
#
# **Layer 3 Devices**<br>
# - Routers
# - Multilayer Switches
#     - regular switch and router combined
#     - switch is always a layer 2 device unless it is multilayer
# - IP Addresses

# %% [markdown]
# ### Layer 4: Transport Layer
#
# **Course** [Transport Layer](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185554#content)
#
# **Transport Layer**<br>
# - Dividing line between the upper and lower layers of the OSI model
#
# **Transmission Control Protocol (TCP)**<br>
# - **Segments**
# - Connection-oriented protocol
# - Provides reliable data delivery
# - If a segment is lost, the protocol will ask for acknowledgment each time
# - If it doens't get an acknowledgment, it will resend the data
# - sending, listening, verifying
# - three way handshake: SYN, SYN-ACK, ACK
# - like certified mail, used for all data that needs to be acknowledged
#
# **User Datagram Protocol (UDP)**<br>
# - **Datagrams**
# - Connectionless protocol
# - Unreliable data delivery
# - No acknowledgment
# - Good for audio and video streaming
# - If a packet gets dropped in this application, its not a big deal
# - In these situations TCP would cause way more buffering, larger, and use more bandwidth
#
# | **TCP**                                           | **UDP**                                           |
# |---------------------------------------------------|--------------------------------------------------|
# | Connection-oriented                                | Connectionless                                   |
# | Reliable   | Unreliable   |
# | Connection-oriented            | onnectionless                      |
# | Segment retransmission and flow control through windowing                  | No windowing or retransmission                  |
# | Segment sequencing               | No sequencing                   |
# | Acknowledges segments | No acknowledgement    |
# | Ensures packets are delivered in order            | Packets may arrive out of order or be dropped   |
# | example: web browsing, email, file transfer, etc. | example: audio and video streaming, online gaming, etc. |
#
# **Windowing**<br>
# - Allows the clients to adjust the amount of data (more or less) in each segment
# - Helps to prevent network congestion
# - Example: large download where the time estimated to download changes from long time to short time and vice versa
# - Why? Because the window size is changing, issues on the network
# - More retrainsmissions, more congestion, more dropped packets
# - Less retransmissions, less congestion, less dropped packets
#
# **Buffering**<br>
# - Occurs when data is temporarily stored in memory
# - If network is congested, data is stored in buffer until it can be transmitted
# - Buffering can cause latency and jitter
#
# **Layer 4 Devices**<br>
# - Transport Protocols
#     - TCP
#     - UDP
# - WAN Accelerators
# - Load Balancers
# - Firewalls

# %% [markdown]
# ### Layer 5: Session Layer
#
# **Course** [Session Layer](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185560#content)
#
# **Session Layer**<br>
# - Keeps conversations between devices organized
#
#
# **Session Establishment**<br>
# - Check user credentials
# - Assign numbers to the session
# - Establish the session
#
# **Session Maintenance**<br>
# - Data transfers back and forth across the network
# - Transfer Data
# - Reestablish the session if it is lost
# - Acknowledge receipt of data
#
# **Session Termination**<br>
# - Ending the session when transfer is done
# - When one side of the conversation ends the session, the other side must also end the session
#
# **Layer 5 Devices**<br>
# - H.323
#     - Used to set up, maintain, and tear down voice and video connections
#     - Real-time transport protocol (RTP)
#     - Streaming media (audio/video)
# - NetBIOS
#     - Used to share files over a network

# %% [markdown]
# ### Layer 6: Presentation Layer
#
# **Course** [Presentation Layer](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185562#content)
#
# **Presentation Layer**<br>
# - Formats data to be exchanged and secures that data with proper encryption
#
# **Data Formatting**<br>
# - Data is formated by the computer to have compatibility between different devices
# - Amaerican Standard Code for Information Interchange (ASCII)
#     - Text-based language\
#     - Ensures data is readable by receiving device
#     - Provides proper data structures
#     - Negotiates data transfer syntax for Application Layer (Layer 7)
# - GIF, JPEG, PNG
#     - Image formats
#
# **Data Encryption**<br>
# - Used to scrambe data in transit to keep it secure
# - Transport Layer Security (TLS)
#     - Encrypts data between the transport layer and the application layer
# - Secure Sockets Layer (SSL)
#     - Used to secure data between the transport layer and the application layer
# - Secure Hypertext Transfer Protocol (HTTPS)
#     - Used to secure data between the transport layer and the application layer
#
# **Layer 6 Devices**<br>
# - Scripting Languages
# - Encryption Protocols
# - Picture Formats
# - Movie Formats
# - Standard Text Formats

# %% [markdown]
# ### Layer 7: Application Layer
#
# **Course** [Application Layer](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185564#content)
#
# **Application Layer**<br>
# - Provides network services to applications
# - This is where the user interacts with the network
#
# **Application Services**<br>
# - Unites communication components foom more than one network application
#
# **Service Advertisement**<br>
# - Allows devices to advertise services to other devices on the network
#
# **Layer 7 Devices**<br>
# - Web Browsers
# - Email Clients
# - File Transfer Protocol (FTP)
# - Remote Access
# - Domain Name System (DNS)

# %% [markdown]
# ### Encapsulation and De-encapsulation
#
# **Course** [Encapsulation and De-encapsulation](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185566#content)
#
# **Encapsulation**<br>
# - The process of putting headers (and trailers) around data
#
# **Ptotocol Data Unit (PDU)**<br>
# - A single unit of information transmitted in a computer network
#
# **Control Flags**<br>
# - SYN (Synchronize):
#     - used to synchronize sequence numbers during the 3-way handshake
# - ACK (Acknowledgment):
#     - used during 3 way handshake
#     - acknowledge receipt of packets
# - FIN(Finished):
#     - finish the session
#     - uses the 3-way handshake and the syn flag
# - RST (Reset):
#     - reset the connection
#     - when a client or server receives a packet that was not expected
# - PSH (Push):
#     - used to ensure data is given priority and processed at sending or receiving ends
#     - push data to the application layer
# - URG (Urgent):
#     - Similar to PSH and identifies incoming data as urgent
#
# **UDP Header (8 bytes)**<br>
# - Source Port (2 bytes)
#     - where the data is coming from
# - Destination Port (2 bytes)
#     - where the data is going to
# - Length (2 bytes)
#     - length of the entire packet
# - Checksum (2 bytes)
#     - used to verify the integrity of the packet
#
# **IP Header (20 bytes)**<br>
# - Vision (4 bits)
#     - version of the IP protocol
# - Length (4 bits)
#     - length of the header
# - Type of Service (8 bits)
#     - used to prioritize packets
# - Total Length (16 bits)
#     - length of the entire packet
# - Identification (16 bits)
#     - used to identify the packet
# - Flags (3 bits)
#     - used to control fragmentation
# - Fragment Offset (13 bits)
#     - used to reassemble fragmented packets
# - Time to Live (8 bits)
#     - how long the packet can live on the network
# - Protocol (8 bits)
#     - what protocol is being used
# - Header Checksum (16 bits)
#     - used to verify the integrity of the header
# - Source IP Address (32 bits)
#     - where the data is coming from
# - Destination IP Address (32 bits)
#     - where the data is going to
# - Options (variable)
#     - additional information
#
# **Ethernet Header (14 bytes)**<br>
# - Destination MAC Address (6 bytes)
#     - where the data is going to
# - Source MAC Address (6 bytes)
#     - where the data is coming from
# - Type (2 bytes)
#     - what protocol is being used
# - VLAN Tag (Optional) (4 bytes)
#     - used to identify VLANs
#
# **MAC Address**<br>
# - Physical address that is used to identify devices on a network
# - Allows source to find destination
#
# **EtherType**<br>
# - Identifies the protocol being used
# - Examples: IPv4, IPv6, ARP, etc.

# %% [markdown]
# ### Section Quiz
#
# **Course** [Section Quiz](https://www.udemy.com/course/comptia-network-009/learn/quiz/6222684#overview)
#
# Question 1:
# Which type of network device operates at layer 1 of the OSI model and requires connected devices to operate at half-duplex using CSMA/CD?
# - A. Switch
# - B. Bridge
# - C. Router
# - D. Hub
#
# Answer: D. Hub
#
# A hub is a network hardware device for connecting multiple Ethernet devices together and making them act as a single network segment. It operates at the physical layer (Layer 1) of the OSI model. All devices connected by a hub are in a single collision domain and a single broadcast domain, so it must use half-duplex for communication and CSMA/CD. A switch operates at layer 2 of the OSI model and provides more advanced functionality than a hub. A bridge also operates at layer 2. It connects two separate network segments. A router operates at layer 3 and forwards data packets among networks.
#
# Question 2:
# Which of the following applies to data as it travels from Layer 1 to Layer 7 of the OSI model?
# - A. Encapsulation
# - B. De-encapsulation
# - C. Tagging
# - D. Tunneling
#
# Answer: B. De-encapsulation
#
# De-encapsulation in networking is performed at the receiver side or destination side as data moves from layer 1 to layer 7 of the OSI model. As information travels up the layers of the OSI layer, information added from the sender’s encapsulation process is removed layer by layer. Tagging typically refers to the process of adding additional information or labels to data packets for specific purposes. Tunneling involves encapsulating one network protocol within another protocol for data transference. Encapsulation is the reverse process of de-encapsulation.
#
# Question 3:
# According to the OSI model, at which of the following layers is data encapsulated into a frame?
# - A. Layer 1
# - B. Layer 2
# - C. Layer 3
# - D. Layer 4
#
# Answer: B. Layer 2
#
# The data layer, or layer 2, is the second layer of the seven-layer OSI model. The data link layer encapsulates data into frames for delivery between nodes on the same network. Data is **transmitted** at Layers **5, 6, and 7** of the OSI model. At Layer **4**, the data is **encapsulated into segments**. At layer **3**, the segments are **encapsulated into packets**. At layer **2**, the packets are **encapsulated into frames**. At layer **1**, the frames are **encapsulated into bits**.
#
# Question 4:
# Which network device operates at layer 2?
# A. Repeater
# B. Switch
# C. Router
# D. Firewall
#
# Answer: B. Switch
#
# A switch operates at layer 2 of the OSI model, the data link layer. It uses MAC addresses to forward data between devices on the same network segment. A repeater operates at layer 1, the physical layer, and simply regenerates signals to extend the reach of a network. A router operates at layer 3, the network layer, and forwards data between different networks. A firewall operates at layer 4, the transport layer, or higher layers to filter and control network traffic.
#
# Question 5:
# What layer of the OSI model is responsible for data encryption and character set conversion, such as ASCII to UTF-8?
# A. Layer 7
# B. Layer 6
# C. Layer 5
# D. Layer 4
#
# Answer: B. Layer 6
#
# The presentation layer (Layer 6) of the OSI model is responsible for data encryption, character set conversion, and other data formatting tasks. It ensures that data is presented in a format that can be understood by the application layer (Layer 7). Layer 7 is the application layer and is responsible for providing network services to applications. Layer 5 is the session layer, which establishes, maintains, and terminates connections between devices. Layer 4 is the transport layer, which provides end-to-end communication services.

# %% [markdown]
# ## Ports and Protocols
#
# **Course** [Ports and Protocols](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185574?start=15#overview)
#
# **Ports**<br>
# - Virtual entry/exit point for communications used by software applications to exchange data
#
# **Protocols**<br>
# - Set of rules that govern how data is transmitted over a network

# %% [markdown]
# ### Network Port Fundamentals
#
# **Course** [Network Port Fundamentals](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185578#overview)
#
# **Port**<br>
# - A logical opening in a compute that represents a service or application
# - Listening and waiting for traffic
# - Numbered from 0 to 65535
#
# **Well-Known Ports**<br>
# - 0 to 1023
#
# **Registered Ports**<br>
# - 1024 to 49151
#
# **Ephemeral Ports**<br>
# - 49152 to 65535

# %% [markdown]
# ### Tranmission Control Protocol (TCP)
#
# **Course** [Transmission Control Protocol (TCP)](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185588#overview)
#
# **Transmission Control Protocol (TCP)**<br>
# - A fundamental protoco within the Internet protocol swuite that consits of set of rules that govern the exhange of data
# - Error checking, data sequencing, and acknowledgement
# - Operates at Layer 4 (Transport Layer) of the OSI model
# - Ensures reliable transmission of data
# - Breaks down larger messages into smaller packets
# - Reassembles packets at the destination
# - 3-way handshake: SYN, SYN-ACK, ACK
# - Error checking and flow control
#     - TCP uses sequence number and acknowledgment messages to assure the data is being received correctly
#     - If packet is lost or corrupted, the receiver will request a retransmission
#     - Flow control is used to prevent the sender from overwhelming the receiver with data
#     - Windowing is used to control the amount of data sent at one time
# - Port
#     - TCP uses port numbers to identify the application or service that is sending or receiving data

# %% [markdown]
# ### User Datagram Protocol (UDP)
#
# **Course** [User Datagram Protocol (UDP)](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185594#content)
#
# **User Datagram Protocol (UDP)**<br>
# - communication protocol used across the internet for time-senstive transmissions
# - low latency and reduced processing overheadh
# - But... no error checking, no sequencing, no acknowledgment
# - Operates at Layer 4 (Transport Layer) of the OSI model
# - connectionless communication model
# - no handshaking or windowing
# - UDP does not need acknowledgment of receipt of data, leading to faster transmission, but it is less reliable than TCP
# - UDP is used for real-time applications like video streaming, online gaming where speed is more important than reliability
# - UDP relies on ports to help diffentiate bewteen applications and services
# - Checksum provides some minimal protection agiainst data corruption

# %% [markdown]
# ### Internet Control Message Protocol (ICMP)
#
# **Course** [Internet Control Message Protocol (ICMP)](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185598#content)
#
# **Internet Control Message Protocol (ICMP)**<br>
# - Integral part of the Internet Protocol (IP) suite
#     - a set of networking protocols used on the internet
# - Network layer protocol used to report errors and exchange information
# - used for various purposes
#     - when a service or host is unreachable
#     - when a packet's time to live has expired
#     - when a router cannot forwarrd packets due to its buffer being full
# - ping: used to test connectivity between devices
# - ICMP messages consist of 3 parts
#     - Type: the type of message
#     - Code: the subtype of the message
#     - Checksum: used to verify the integrity of the message
# - Hackers expliot ICMP
#     - ICMP flood: sends a large number of ICMP packets to a target to overwhelm it
#         - DDoS attack: when the attacker uses a network of compromised computers (botnet) to generate a significant amount of traffic to overwhelm a target
#     - Ping of Death: sends a large ICMP packet to a target to crash
#         - attack that exploits a vulnerability that existed in older, unpatched systmes
#         - the attacker sends malformed or oversiazed packets using the ICMP protocol to crash the target system
# - Because of these vulnerabilities many network administrators block ICMP traffic at the firewall level

# %% [markdown]
# ### Web Ports and Protocols
#
# **Course** [Web Ports and Protocols](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185606?start=45#content)
#
# **Web Ports and Protocols**<br>
# - Standard rules and numerical gateways that are used to govern data transmission and communication over the internet for websites and web pages
# - 2 manin ports used for the web
#     - port 80: HTTP
#     - port 443: HTTPS
# - Port 80: Hypertext Transfer Protocol (HTTP)
#     - application layer protocol
#     - enables plain text communication between clients and servers
#     - unencrypted/less secure
#     - used for non-sensitive data
# - Port 443: Hypertext Transfer Protocol Secure (HTTPS)
#     - TLS/SSL encrypted
#     - used to transfer data between a web server and a web browser
#     - encrypted/more secure
#     - used for sensitive data
#     - Over 95% of web traffic is encrypted using HTTPS

# %% [markdown]
# ### Email Ports and Protocols
#
# **Course** [Email Ports and Protocols](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185608#content)
#
# **Email Ports and Protocols**<br>
# - Standard rules and numerical gateways that are used to govern data transmission and communication over the internet for email
# - Ensure that message are sent, received, and managed effeciently
#
# **Simple Mail Transfer Protocol (SMTP)**<br>
# - used to send email messages
# - Operates on port 25
# - Only used for sending email, not receiving
# - Insecure protocol, because data is sent in plain text
#     - SMTPS: secure version of SMTP that uses SSL/TLS encryption
#     - creates an encrypted tunnel between the client and server
#     - Operates on port 465 or 587
#
# **Post Office Protocol (POP3)**<br>
# - used to retrieve email messages from a server
# - Operates on port 110
# - POP3 downloads messages to the client device and deletes them from the server
# - POP3 is not designed to sync messages across multiple devices
# - older protocol, less secure
# - POP3S: secure version of POP3 that uses SSL/TLS encryption
#     - operates on port 995
#
# **Internet Message Access Protocol (IMAP)**<br>
# - used to retrieve email messages from a server
# - Operates on port 143
# - IMAP downloads messages to the client device but leaves a copy on the server
# - IMAP is designed to sync messages across multiple devices
# - newer protocol, more secure
# - IMAPS: secure version of IMAP that uses SSL/TLS encryption
#     - operates on port 993

# %% [markdown]
# ### File Transfer Ports and Protocols
#
# **Course** [File Transfer Ports and Protocols](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185614#content)
#
# **File Transfer Ports and Protocols**<br>
# - Specialized rules and procedures that are utilized for the transfer of files between devices on a network
# - operate on designated ports
# - act as doorways for data transfer
#
# **File Transfer Protocol (FTP)**<br>
# - one of the oldest protocols used for file transfer
# - operates on port 21 or 20
#     - port 21: control channel
#     - port 20: data channel
# - FTP is unencrypted, making it less secure
#
# **Secure File Transfer Protocol (SFTP)**<br>
# - secure version of FTP
# - operates on port 22
# - uses SSH to encrypt data during transfer
# - SFTP is tunneling an FTP protocol through an SSH connection, which has already been encrypted
#
# **Trivial File Transfer Protocol (TFTP)**<br>
# - simple file transfer protocol
# - operates on port 69
# - for sending files when minimal security is sufficient
#
# **Server Message Block (SMB)**<br>
# - used for file sharing on Windows networks
# - operates on port 445
# - SMB is used to share files, printers, and other resources between devices on a network
# - SMB is used insdie a LAN, not over the internet

# %% [markdown]
# ### Remote Access Ports and Protocols
#
# **Course** [Remote Access Ports and Protocols](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185622#content)
#
# **Remote Access Ports and Protocols**<br>
# - Standard rules and numerical gateways that are used to govern data transmission and communication over the internet for remote access
#
# **Secure Shell (SSH)**<br>
# - used to securely access a remote computer over an unsecured network
# - operates on port 22
# - SSH encrypts data during transmission via a secure tunnel
#
# **Telnet**<br>
# - used to access a remote computer over the same network
# - operates on port 23
# - Telnet is unencrypted, making it less secure
# - Telnet is not recommended for use over the internet
#
# **Remote Desktop Protocol (RDP)**<br>
# - proprietary protocol developed by Microsoft
# - provides a graphical interface for remote access to Windows computers
# - operates on port 3389
# - RDP encrypts data during transmission
# - uses smart card authentication for secure access
# - offers bandwidth optimization for better performance

# %% [markdown]
# ### Network Service Ports and Protocols
#
# **Course** [Network Service Ports and Protocols](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185650#content)
#
# **Network Service Ports and Protocols**<br>
# - differenct services that ensure network devices can discover each other, communicate effectively, and relay important system information
#
# **Domain Name System (DNS)**<br>
# - used to translate domain names into IP addresses that computers can use to identify each other on the network
# - DNS uses port 53 by default
# - operates on both UDP and TCP
#     - UDP is used for small messages
#     - TCP is used for larger messages
#
# **Dynamic Host Configuration Protocol (DHCP)**<br>
# - used to automate the assignment of IP addresses, subnet masks, mass gateways, and other network configuration parameters to devices on a network
# - listen for clien requests on port 67, and will receive responses on port 68 using UDP
#
# **SQL Sevices**<br>
# - protocols used by database servers to manage queries and control operations fom the client applications that are requesting them
# - Microsoft SQL Server: port 1433
# - MySQL: port 3306
#
# **Simple Network Management Protocol (SNMP)**<br>
# - used or collecting information from and configuring differnt network devices like servers, printers, hubs, switches, and routers over an IP Network
# - SNMP uses port 161 for sending requests and port 162 for receiving responses
# - crucial for networks diagnostics and troubleshooting, as well as performance monitoring and management
#
# **System Logging (Syslog)**<br>
# - standard for message logging
# - allows devices to send event messages across IP networks to a centralized logging server (syslog server)

# %% [markdown]
# ### Other Network Service Ports and Protocols
#
# **Course** [Other Network Service Ports and Protocols](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185654#content)
#
# **Network Time Protocol (NTP)**<br>
# - used to synchronize the clocks of computers on a network
# - operates on port 123, using the UDP (user datagram protocol)
#
# **Session Initiation Protocol (SIP)**<br>
# - used for initiating, maintaining, and terminating real-time sessions that involve video, voice, messaging, and other communications applications
# - operates on port 5060 and 5061 usually
#
# **Lightweight Directory Access Protocol (LDAP)**<br>
# - used to access and manage directory information services
# - commonly used in eamil systems, VPNs, and other network services
# - operates on port 389, using both TCP and UDP
# - LDAP over SSL (LDAPS) uses port 636
#     - version of LDAP that uses SSL/TLS to encrypt data during transmission

# %% [markdown]
# ### Section Quiz
#
# **Question 1:**
# What protocol is commonly associated with port 53?
#
# Answer: **DNS** uses port 53 for domain name resolution queries and responses. This association is well-established in networking protocols. HTTP typically uses port 80. FTP commonly uses ports 20 and 21 for data transfer. SSH is associated with port 22 for secure shell connections.
#
# **Question 2:**
# Which protocol is connection-oriented and ensures reliable data delivery by establishing a virtual circuit between the sender and receiver?
#
# Answer: **TCP** (Transmission Control Protocol) is connection-oriented, providing reliable, ordered, and error-checked delivery of data by establishing a virtual circuit between sender and receiver. UDP is connectionless, suitable for real-time applications but does not guarantee reliable delivery. ICMP is used for network diagnostics, error reporting, and is connectionless, not designed for data transfer. GRE is a tunneling protocol, not inherently providing reliable data delivery; it encapsulates various network layer protocols for routing purposes.
#
# **Question 3:**
# Which statement accurately describes characterists of a UDP connection?
#
# Answer: **UDP is suitable for real-time applications due to its low latency**: UDP (User Datagram Protocol) is connectionless and does not establish a connection before sending data. This lack of connection setup contributes to lower latency, making it suitable for real-time applications like streaming, gaming, and voice communication. UDP is connectionless, not connection-oriented, and it does not ensure reliable data delivery. UDP does not provide error checking or retransmission of lost packets. UDP does not guarantee in-order delivery of data packets; packets may arrive out of order.
#
# **Question 4:**
# Which port is commonly used for receiving emails from a mail server?
#
# Answer: **Port 110** is commonly associated with the POP3 (Post Office Protocol version 3) protocol, used for receiving emails from a mail server. Port 80 is typically associated with HTTP, not email protocols. Port 443 is commonly associated with HTTPS (HTTP Secure). Port 25 is commonly associated with SMTP (Simple Mail Transfer Protocol), which is used for sending emails, not receiving them.
#
# **Question 5:**
# Which port and protocol combination(s) are commonly associated with Remote Desktop Protocol (RDP)?
#
# Answer: **RDP** (Remote Desktop Protocol) primarily uses TCP, not UDP, on port 3389. Ports 5060/5061 are commonly associated with SIP (Session Initiation Protocol) used for VoIP, not RDP.

# %% [markdown]
# ## Media and Cabeling
#
# **Course** [Media and Cabeling](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185666?start=75#content)
#
# **Media**<br>
# - Physical means of transmitting data between devices
# - Types: copper, fiber, radio waves
#
# **Domain 1**
# - Networking Concepts
#
# **Domain 5**
# - Network Media and Topologies
#
# **Objective 1.5**
# - Compare and contrast different media types and associated properties
#
# **Objective 5.5**
# - Given a scenario, select the appropriate cabling type and media
#
# **Topics**
# - Copper Media
# - Copper Network Connections
# - Buiding a Copper Caple
# - Fiber Optic Media
# - Fiber Optic Network Connections
# - Transceivers
# - Review

# %% [markdown]
# ### Copper Media
#
# **Course** [Copper Media](https://www.udemy.com/course/comptia-network-009/learn/lecture/42185668#content)
#
# **Copper Media**<br>
# - default type of cable used in networks for decades
#
# **IEEE 802.3**<br>
# - defines the physical layer and data link layer's media access control (MAC) of wired Ethernet
# - commonly used in LANs and WANs
# - most common copper media is twisted pair cable
#
# **Twisted Pair Cable**<br>
# - consists of pairs of insulated copper wires twisted together
# - reduces electromagnetic interference (EMI) and crosstalk
# - used for both data and voice transmission
# - two types: unshielded twisted pair (UTP) and shielded twisted pair (STP)
#     - UTP: most common, less expensive, used in most Ethernet networks
#         - support easier installations, but more susceptible to EMI and noise which degrade signal quality
#     - STP: more expensive, used in environments with high EMI
#         - better at protecting against EMI and noise, but more difficult to install
# - CAT 5: 100 Mbps, 100 meters, 100 MHz
# - CAT 5e: 1 Gbps, 100 meters, 100 MHz
#     - contains more twists per inch than CAT 5, reducing crosstalk
# - CAT 6: 1 Gbps, 100 meters, or up to 10 Gbps @ 55 meters or less,  250 MHz
# - CAT 6a: 10 Gbps, 100 meters, 500 MHz
# - CAT 7: 10 Gbps, 100 meters, 600 MHz
# - CAT 8: 40 Gbps, 30 meters, 2000 MHz
#     - designed for crucial high-speed data transfer over short distances
#
# **Key Features of Twisted Pair in CAT Cables:**<br>
# 1. **Electromagnetic Interference (EMI) Reduction**:
#    - The twisting of pairs minimizes the effect of external electromagnetic interference (EMI) by canceling out induced noise.
#
# 2. **Crosstalk Reduction**:
#    - Twisted pairs reduce crosstalk (signal interference between pairs), which is crucial in maintaining signal integrity in network communications.
#
# 3. **Pairs and Standards**:
#    - CAT cables typically contain **four pairs of twisted wires**, with different categories (e.g., CAT5e, CAT6, CAT6a, CAT7) having variations in:
#      - **Number of twists per inch**: Higher categories often have more twists per inch for better performance.
#      - **Shielding**: Some cables (e.g., S/FTP or F/UTP) include shielding around individual pairs or the entire cable to further reduce interference.
#
# **Examples of CAT Cable Categories:** <br>
# 1. **CAT5e (Enhanced)**:
#    - Common for Ethernet connections.
#    - Twisted pairs but unshielded (UTP).
#
# 2. **CAT6**:
#    - Higher frequency support.
#    - Tighter twists and sometimes includes shielding.
#
# 3. **CAT7**:
#    - Individually shielded pairs (S/FTP) for better performance.
#
#
# **Coaxial Cable**<br>
# - consists of a single copper conductor surrounded by insulation, a braided shield, and an outer jacket
# - used for cable television, internet, and some Ethernet networks
# - more resistant to EMI than twisted pair
# - RG-6: used for cable television and internet
#    - good for high-speed data transmission
# - RG-59: used for cable television
#    - less expensive, but less effective for high-speed data transmission
# - Most modern coaxial cables can support speeds up to 1 Gbps up to around 300 meters
# - Direct Attach Copper (DAC) cables: used for short-distance connections in data centers
#     - provide high-speed connections between switches, routers, and servers
#     - cost-effective and easy to install
#     - limited to short distances (up to 10 meters)
#     - DAC active: 100 Gbps @ 15 meters or less
#     - DAC passive: 100 Gbps @ 7 meters or less
#
# **Twinaxial Cable**<br>
# - often a component of a DAC assembly
# - another specialized form of cabling
# - used for high-speed data transmission in data centers, where interference and crosstalk is a problem
# - unlike coaxial, twinaxial has two inner conductors separated by insulation
# - commonly used for SFPT+ (Small Form-Factor Pluggable Plus) and QSFP (Quad Small Form-Factor Pluggable Plus) applications between two routers or switches
# - twinaxial cables are less susceptible to EMI and crosstalk than coaxial cables
#
# **Plenum Cable**<br>
# - prevents the spread of fire and toxic fumes in the event of a fire
# - prevent the amount of smoke and toxic fumes that are released in the event of a fire
#
# **Non-Plenum Cable**<br>
# - used in areas where fire safety is not a concern
# - less expensive than plenum cable
